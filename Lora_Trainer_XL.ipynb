# %% [markdown]
# # 🌟 XL Lora Trainer by Hollowstrawberry
#
# Colab Premium is recommended. Ideally you'd be changing the runtime to an A100 and use the maximum batch size, it will be several times faster.
#
# This colab is possible by open source code from talented people:
# * [kohya-ss](https://github.com/kohya-ss/sd-scripts)
# * [derrian-distro](https://github.com/derrian-distro/LoRA_Easy_Training_scripts_Backend/)
# * [Linaqruf](https://github.com/Linaqruf/kohya-trainer)
# * [Jelosus2](https://github.com/Jelosus2/LoRA_Easy_Training_Colab)

# %% [markdown]
# ### ⭕ Disclaimer
# The purpose of this document is to research bleeding-edge technologies in the field of machine learning.
# Please read and follow the [Google Colab guidelines](https://research.google.com/colaboratory/faq.html) and its [Terms of Service](https://research.google.com/colaboratory/tos_v3.html).

# %% [markdown]
# | |GitHub|🇬🇧 English|🇪🇸 Spanish|
# |:--|:-:|:-:|:-:|
# | 🏠 **Homepage** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab) | | |
# | 📊 **Dataset Maker** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Dataset_Maker.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Dataset_Maker.ipynb) | [![Abrir en Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge-spanish.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Spanish_Dataset_Maker.ipynb) |
# | ⭐ **Lora Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb) | [![Abrir en Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge-spanish.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Spanish_Lora_Trainer.ipynb) |
# | 🌟 **XL Lora Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL.ipynb) |  |
# | 🌟 **Legacy XL Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL_Legacy.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL_Legacy.ipynb) |  |

# %%
import os
import re
import toml
from time import time
from IPython.display import Markdown, display
import warnings

warnings.filterwarnings("ignore")

# These carry information from past executions
if "model_url" in globals():
  old_model_url = model_url
else:
  old_model_url = None
if "dependencies_installed" not in globals():
  dependencies_installed = False
if "model_file" not in globals():
  model_file = None

# These may be set by other cells, some are legacy
if "custom_dataset" not in globals():
  custom_dataset = None
if "override_dataset_config_file" not in globals():
  override_dataset_config_file = None
if "continue_from_lora" not in globals():
  continue_from_lora = ""
if "override_config_file" not in globals():
  override_config_file = None

#try:
#  LOWRAM = int(next(line.split()[1] for line in open('/proc/meminfo') if "MemTotal" in line)) / (1024**2) < 15
#except:
#  LOWRAM = True

COMMIT = "47ef6ed843ee1951cd07838c5fdcca60c954130c"
LOWRAM = True
LOAD_TRUNCATED_IMAGES = True
BETTER_EPOCH_NAMES = True
FIX_DIFFUSERS = True


#@title ## 🚩 Start Here

#@markdown ### ▶️ Setup
#@markdown Your project name will be the same as the folder containing your images. Spaces aren't allowed.
project_name = "zazi" #@param {type:"string"}
project_name = project_name.strip()
#@markdown The folder structure doesn't matter and is purely for comfort. Make sure to always pick the same one. I like organizing by project.
folder_structure = "Organize by category (MyDrive/lora_training/datasets/project_name)" #@param ["Organize by category (MyDrive/lora_training/datasets/project_name)", "Organize by project (MyDrive/Loras/project_name/dataset)"]
#@markdown Decide the model that will be downloaded and used for training. You can also choose your own by pasting its download link, or a file in your Google Drive starting with `/content/drive/MyDrive`.
training_model = "Stable Diffusion XL 1.0 base" #@param ["Pony Diffusion V6 XL", "Illustrious XL 0.1", "NoobAI V-Pred 1.0", "NoobAI Eps 1.1", "Animagine XL V3", "Stable Diffusion XL 1.0 base"]
optional_custom_training_model = "" #@param {type:"string"}
custom_model_is_diffusers = False #@param {type:"boolean"}
custom_model_is_vpred = False #@param {type:"boolean"}
#@markdown Use wandb if you want to visualize the progress of your training over time.
wandb_key = "" #@param {type:"string"}

load_diffusers = custom_model_is_diffusers and len(optional_custom_training_model) > 0
vpred = custom_model_is_vpred and len(optional_custom_training_model) > 0

if optional_custom_training_model:
  model_url = optional_custom_training_model
elif "Pony" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/hollowstrawberry/67AB2F"
  else:
    model_url = "https://civitai.com/api/download/models/290640"
    model_file = "/content/ponyDiffusionV6XL.safetensors"
elif "Animagine" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/cagliostrolab/animagine-xl-3.0"
  else:
    model_url = "https://civitai.com/api/download/models/293564"
    model_file = "/content/animagineXLV3.safetensors"
elif "Illustrious" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/OnomaAIResearch/Illustrious-xl-early-release-v0"
  else:
    model_url = "https://huggingface.co/OnomaAIResearch/Illustrious-xl-early-release-v0/resolve/main/Illustrious-XL-v0.1.safetensors"
elif "NoobAI Eps" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-1.1"
  else:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-1.1/resolve/main/NoobAI-XL-v1.1.safetensors"
elif "NoobAI V-Pred" in training_model:
  vpred = True
  if load_diffusers:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-Vpred-1.0"
  else:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-Vpred-1.0/resolve/main/NoobAI-XL-Vpred-v1.0.safetensors"
else:
  if load_diffusers:
    model_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0"
  else:
    model_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors"

if load_diffusers:
  vae_file = ""
else:
  vae_url = ""
  vae_file = ""

model_url = model_url.strip()

#@markdown ### ▶️ Processing
resolution = 1024 #param {type:"slider", min:768, max:1536, step:128}
caption_extension = ".txt" #@param [".txt", ".caption"]
#@markdown Shuffling anime tags in place improves learning and prompting. An activation tag goes at the start of every text file and will not be shuffled.<p>
shuffle_tags = True #@param {type:"boolean"}
shuffle_caption = shuffle_tags
activation_tags = "1" #@param [0,1,2,3]
keep_tokens = int(activation_tags)

#@markdown ### ▶️ Steps <p>
#@markdown Your images will repeat this number of times during training. I recommend that your images multiplied by their repeats is around 100, or 1 repeat with more than 100 images.
num_repeats = 2 #@param {type:"number"}
#@markdown Choose how long you want to train for. A good starting point is around 10 epochs or around 2000 steps.<p>
#@markdown One epoch is a number of steps equal to: your number of images multiplied by their repeats, divided by batch size. <p>
preferred_unit = "Epochs" #@param ["Epochs", "Steps"]
how_many = 10 #@param {type:"number"}
max_train_epochs = how_many if preferred_unit == "Epochs" else None
max_train_steps = how_many if preferred_unit == "Steps" else None
#@markdown Saving more epochs will let you compare your Lora's progress better.
save_every_n_epochs = 1 #@param {type:"number"}
keep_only_last_n_epochs = 10 #@param {type:"number"}
if not save_every_n_epochs:
  save_every_n_epochs = max_train_epochs
if not keep_only_last_n_epochs:
  keep_only_last_n_epochs = max_train_epochs

#@markdown ### ▶️ Learning
#@markdown The learning rate is the most important for your results. If your Lora produces black images, lower the unet and text encoder to 1e-4 and 1e-5 respectively, or even lower. <p>
#@markdown If you're training a style you can choose to set the text encoder to 0.
unet_lr = 1e-4 #@param {type:"number"}
text_encoder_lr = 5e-5 #@param {type:"number"}
#@markdown The scheduler is the algorithm that guides the learning rate. If you're not sure, pick `constant` and ignore the number. I personally recommend `cosine_with_restarts` with 3 restarts.
lr_scheduler = "cosine_with_restarts" #@param ["constant", "cosine", "cosine_with_restarts", "constant_with_warmup", "linear", "polynomial", "rex"]
lr_scheduler_number = 3 #@param {type:"number"}
#@markdown Steps spent "warming up" the learning rate during training for efficiency. I recommend leaving it at 5%.
lr_warmup_ratio = 0.05 #@param {type:"slider", min:0.0, max:0.2, step:0.01}
lr_warmup_steps = 0
#@markdown These settings may produce better results. min_snr_gamma adjusts loss over time. ip_noise_gamma adjusts random noise.
min_snr_gamma_enabled = True #@param {type:"boolean"}
min_snr_gamma = 8.0 #@param {type:"slider", min:4, max:16.0, step:0.5}
ip_noise_gamma_enabled = False #@param {type:"boolean"}
ip_noise_gamma = 0.05 #@param {type:"slider", min:0.05, max:0.1, step:0.01}
#@markdown Multinoise may help with color balance (darker darks, lighter lights).
multinoise = True #@param {type:"boolean"}

#@markdown ### ▶️ Structure
#@markdown LoRA is the classic type and good for a variety of purposes. LoCon is good with artstyles as it has more layers to learn more aspects of the dataset.
lora_type = "LoRA" #@param ["LoRA", "LoCon"]

#@markdown Below are some recommended XL values for the following settings:

#@markdown | type | network_dim | network_alpha | conv_dim | conv_alpha |
#@markdown | :---: | :---: | :---: | :---: | :---: |
#@markdown | Regular LoRA | 8 | 4 |   |   |
#@markdown | Style LoCon | 16 | 8 | 16 | 8 |

#@markdown More dim means larger Lora, it can hold more information but more isn't always better.
network_dim = 8 #@param {type:"slider", min:1, max:32, step:1}
network_alpha = 4 #@param {type:"slider", min:1, max:32, step:1}
#@markdown The following two values only apply to the additional layers of LoCon.
conv_dim = 16 #@param {type:"slider", min:1, max:32, step:1}
conv_alpha = 8 #@param {type:"slider", min:1, max:32, step:1}

network_module = "networks.lora"
network_args = None
if lora_type.lower() == "locon":
  network_args = [f"conv_dim={conv_dim}", f"conv_alpha={conv_alpha}"]

#@markdown ### ▶️ Training
#@markdown Adjust these parameters depending on your colab configuration.
#@markdown
#@markdown Higher batch size is often faster but uses more memory.
train_batch_size = 3 #@param {type:"slider", min:1, max:16, step:1}
#@markdown I have found no substantial difference between sdpa and xformers.
cross_attention = "sdpa" #@param ["sdpa", "xformers"]
#@markdown Use `full fp16` for lowest memory usage. The `bf16` options may not work correctly on the free GPU tier.<p>
#@markdown The Lora will be trained with the selected precision, but will always be saved in fp16 format for compatibility reasons.
precision = "full fp16" #@param ["float", "full fp16", "full bf16", "mixed fp16", "mixed bf16"]
#@markdown Caching latents to drive will add a 250KB file next to each image but will use considerably less memory.
cache_latents = True #@param {type:"boolean"}
cache_latents_to_drive = True #@param {type:"boolean"}
#@markdown The following option will turn off shuffle_tags and disable text encoder training.
cache_text_encoder_outputs  = False  # @param {type:"boolean"}

mixed_precision = "no"
if "fp16" in precision:
  mixed_precision = "fp16"
elif "bf16" in precision:
  mixed_precision = "bf16"
full_precision = "full" in precision

#@markdown ### ▶️ Advanced
#@markdown The optimizer is the algorithm used for training. AdamW8bit is the default and works great, while Prodigy manages learning rate automatically and may have several advantages such as training faster due to needing less steps as well as working better for small datasets.
optimizer = "AdamW8bit" #@param ["AdamW8bit", "Prodigy", "DAdaptation", "DadaptAdam", "DadaptLion", "AdamW", "Lion", "SGDNesterov", "SGDNesterov8bit", "AdaFactor", "Came"]
#@markdown Recommended args for AdamW8bit: `weight_decay=0.1 betas=[0.9,0.99]`<p>
#@markdown Recommended args for Prodigy: `decouple=True weight_decay=0.01 betas=[0.9,0.999] d_coef=2 use_bias_correction=True safeguard_warmup=True`<p>
#@markdown Recommended args for AdaFactor: `scale_parameter=False relative_step=False warmup_init=False`<p>
#@markdown Recommended args for Came: `weight_decay=0.04`<p>
#@markdown If Dadapt or Prodigy are selected and the recommended box is checked, the following values will override any previous settings:<p>
#@markdown `unet_lr=0.75`, `text_encoder_lr=0.75`, `network_alpha=network_dim`, `full_precision=False`<p>
recommended_values = True #@param {type:"boolean"}
#@markdown Alternatively set your own optimizer arguments separated by spaces (not commas). Recommended box must be disabled.
optimizer_args = "" #@param {type:"string"}
optimizer_args = [a.strip() for a in optimizer_args.split(' ') if a]

if recommended_values:
  if any(opt in optimizer.lower() for opt in ["dadapt", "prodigy"]):
    unet_lr = 0.75
    text_encoder_lr = 0.75
    network_alpha = network_dim
    full_precision = False
  if optimizer == "Prodigy":
    optimizer_args = ["decouple=True", "weight_decay=0.01", "betas=[0.9,0.999]", "d_coef=2", "use_bias_correction=True", "safeguard_warmup=True"]
  elif optimizer == "AdamW8bit":
    optimizer_args = ["weight_decay=0.1", "betas=[0.9,0.99]"]
  elif optimizer == "AdaFactor":
    optimizer_args = ["scale_parameter=False", "relative_step=False", "warmup_init=False"]
  elif optimizer == "Came":
    optimizer_args = ["weight_decay=0.04"]

if optimizer == "Came":
  optimizer = "LoraEasyCustomOptimizer.came.CAME"

lr_scheduler_type = None
lr_scheduler_args = None
lr_scheduler_num_cycles = lr_scheduler_number
lr_scheduler_power = lr_scheduler_number

if "rex" in lr_scheduler:
  lr_scheduler = "cosine"
  lr_scheduler_type = "LoraEasyCustomOptimizer.RexAnnealingWarmRestarts.RexAnnealingWarmRestarts"
  lr_scheduler_args = ["min_lr=1e-9", "gamma=0.9", "d=0.9"]

# Misc
seed = 42
gradient_accumulation_steps = 1
bucket_reso_steps = 64
min_bucket_reso = 256
max_bucket_reso = 4096


#@markdown ### ▶️ Ready
#@markdown You can now run this cell to cook your Lora. Good luck! <p>


# 👩‍💻 Cool code goes here

root_dir = "/content"
trainer_dir = os.path.join(root_dir, "trainer")
kohya_dir = os.path.join(trainer_dir, "sd_scripts")

venv_python = os.path.join(kohya_dir, "venv/bin/python")
venv_pip = os.path.join(kohya_dir, "venv/bin/pip")
train_network = os.path.join(kohya_dir, "sdxl_train_network.py")

if "/Loras" in folder_structure:
  main_dir      = os.path.join(root_dir, "drive/MyDrive/Loras")
  log_folder    = os.path.join(main_dir, "_logs")
  config_folder = os.path.join(main_dir, project_name)
  images_folder = os.path.join(main_dir, project_name, "dataset")
  output_folder = os.path.join(main_dir, project_name, "output")
else:
  main_dir      = os.path.join(root_dir, "drive/MyDrive/lora_training")
  images_folder = os.path.join(main_dir, "datasets", project_name)
  output_folder = os.path.join(main_dir, "output", project_name)
  config_folder = os.path.join(main_dir, "config", project_name)
  log_folder    = os.path.join(main_dir, "log")

config_file = os.path.join(config_folder, "training_config.toml")
dataset_config_file = os.path.join(config_folder, "dataset_config.toml")


def install_trainer():
  # !apt -y update -qq
  # !apt install -y python3.10-venv aria2 -qq
  # !git clone https://github.com/derrian-distro/LoRA_Easy_Training_scripts_Backend {trainer_dir}
  os.chdir(trainer_dir)
  # !git reset --hard {COMMIT}
  # !chmod 755 ./colab_install.sh
  # !./colab_install.sh

  # fix logging
  # !{venv_pip} uninstall -y rich

  # patch kohya
  os.chdir(kohya_dir)
  if LOAD_TRUNCATED_IMAGES:
    # !sed -i 's/from PIL import Image/from PIL import Image, ImageFile\nImageFile.LOAD_TRUNCATED_IMAGES=True/g' library/train_util.py # fix truncated jpegs error
  if BETTER_EPOCH_NAMES:
    # !sed -i 's/{:06d}/{:02d}/g' library/train_util.py # make epoch names shorter
    # !sed -i 's/"." + args.save_model_as)/"-{:02d}.".format(num_train_epochs) + args.save_model_as)/g' train_network.py # name of the last epoch will match the rest
  if FIX_DIFFUSERS:
    deprecation_utils = os.path.join(kohya_dir, "venv/lib/python3.10/site-packages/diffusers/utils/deprecation_utils.py")
    # !sed -i 's/if version.parse/if False:#/g' {deprecation_utils}
  if wandb_key:
    # !sed -i 's/accelerator.log(logs, step=epoch + 1)//g' train_network.py  # fix warning
    # !sed -i 's/accelerator.log(logs, step=epoch + 1)//g' sdxl_train.py  # fix warning

  os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
  os.environ["BITSANDBYTES_NOWELCOME"] = "1"
  os.environ["SAFETENSORS_FAST_GPU"] = "1"
  os.environ["PYTHONWARNINGS"] = "ignore"
  os.chdir(root_dir)


def validate_dataset():
  global lr_warmup_steps, lr_warmup_ratio, caption_extension, keep_tokens, model_url
  supported_types = (".png", ".jpg", ".jpeg", ".webp", ".bmp")

  if model_url.startswith("/content/drive/") and not os.path.exists(model_url):
    print("💥 Error: The custom training model you specified was not found in your Google Drive.")
    return

  print("\n💿 Checking dataset...")
  if not project_name.strip() or any(c in project_name for c in " .()\"'\\/"):
    print("💥 Error: Please choose a valid project name.")
    return

  # Find the folders and files
  if custom_dataset:
    try:
      datconf = toml.loads(custom_dataset)
      datasets = [d for d in datconf["datasets"][0]["subsets"]]
    except:
      print(f"💥 Error: Your custom dataset is invalid or contains an error! Please check the original template.")
      return
    reg = [d.get("image_dir") for d in datasets if d.get("is_reg", False)]
    datasets_dict = {d["image_dir"]: d["num_repeats"] for d in datasets}
    folders = datasets_dict.keys()
    files = [f for folder in folders for f in os.listdir(folder)]
    images_repeats = {folder: (len([f for f in os.listdir(folder) if f.lower().endswith(supported_types)]), datasets_dict[folder]) for folder in folders}
  else:
    reg = []
    folders = [images_folder]
    files = os.listdir(images_folder)
    images_repeats = {images_folder: (len([f for f in files if f.lower().endswith(supported_types)]), num_repeats)}

  # Validation
  for folder in folders:
    if not os.path.exists(folder):
      print(f"💥 Error: The folder {folder.replace('/content/drive/', '')} doesn't exist.")
      return
  for folder, (img, rep) in images_repeats.items():
    if not img:
      print(f"💥 Error: Your {folder.replace('/content/drive/', '')} folder is empty.")
      return
  test_files = []
  for f in files:
    if not f.lower().endswith((caption_extension, ".npz")) and not f.lower().endswith(supported_types):
      print(f"💥 Error: Invalid file in dataset: \"{f}\". Aborting.")
      return
    for ff in test_files:
      if f.endswith(supported_types) and ff.endswith(supported_types) \
          and os.path.splitext(f)[0] == os.path.splitext(ff)[0]:
        print(f"💥 Error: The files {f} and {ff} cannot have the same name. Aborting.")
        return
    test_files.append(f)

  if caption_extension and not [txt for txt in files if txt.lower().endswith(caption_extension)]:
    caption_extension = ""
  if continue_from_lora and not (continue_from_lora.endswith(".safetensors") and os.path.exists(continue_from_lora)):
    print(f"💥 Error: Invalid path to existing Lora. Example: /content/drive/MyDrive/Loras/example.safetensors")
    return

  # Show estimations to the user

  pre_steps_per_epoch = sum(img*rep for (img, rep) in images_repeats.values())
  steps_per_epoch = pre_steps_per_epoch/train_batch_size
  total_steps = max_train_steps or int(max_train_epochs*steps_per_epoch)
  estimated_epochs = int(total_steps/steps_per_epoch)
  lr_warmup_steps = int(total_steps*lr_warmup_ratio)

  for folder, (img, rep) in images_repeats.items():
    print("📁"+folder.replace("/content/drive/", "") + (" (Regularization)" if folder in reg else ""))
    print(f"📈 Found {img} images with {rep} repeats, equaling {img*rep} steps.")
  print(f"📉 Divide {pre_steps_per_epoch} steps by {train_batch_size} batch size to get {steps_per_epoch} steps per epoch.")
  if max_train_epochs:
    print(f"🔮 There will be {max_train_epochs} epochs, for around {total_steps} total training steps.")
  else:
    print(f"🔮 There will be {total_steps} steps, divided into {estimated_epochs} epochs and then some.")

  if total_steps > 10000:
    print("💥 Error: Your total steps are too high. You probably made a mistake. Aborting...")
    return

  return True


def create_config():
  global dataset_config_file, config_file, model_file

  if override_config_file:
    config_file = override_config_file
    print(f"\n⭕ Using custom config file {config_file}")
  else:
    config_dict = {
      "network_arguments": {
        "unet_lr": unet_lr,
        "text_encoder_lr": text_encoder_lr if not cache_text_encoder_outputs else 0,
        "network_dim": network_dim,
        "network_alpha": network_alpha,
        "network_module": network_module,
        "network_args": network_args,
        "network_train_unet_only": text_encoder_lr == 0 or cache_text_encoder_outputs,
        "network_weights": continue_from_lora or None
      },
      "optimizer_arguments": {
        "learning_rate": unet_lr,
        "lr_scheduler": lr_scheduler,
        "lr_scheduler_type": lr_scheduler_type,
        "lr_scheduler_args": lr_scheduler_args,
        "lr_scheduler_num_cycles": lr_scheduler_num_cycles if lr_scheduler == "cosine_with_restarts" else None,
        "lr_scheduler_power": lr_scheduler_power if lr_scheduler == "polynomial" else None,
        "lr_warmup_steps": lr_warmup_steps if lr_scheduler not in ("cosine", "constant") else None,
        "optimizer_type": optimizer,
        "optimizer_args": optimizer_args or None,
        "loss_type": "l2",
        "max_grad_norm": 1.0,
      },
      "training_arguments": {
        "lowram": LOWRAM,
        "pretrained_model_name_or_path": model_file,
        "vae": vae_file,
        "max_train_steps": max_train_steps,
        "max_train_epochs": max_train_epochs,
        "train_batch_size": train_batch_size,
        "seed": seed,
        "max_token_length": 225,
        "xformers": cross_attention == "xformers",
        "sdpa": cross_attention == "sdpa",
        "min_snr_gamma": min_snr_gamma if min_snr_gamma_enabled else None,
        "ip_noise_gamma": ip_noise_gamma if ip_noise_gamma_enabled else None,
        "no_half_vae": True,
        "gradient_checkpointing": True,
        "gradient_accumulation_steps": gradient_accumulation_steps,
        "max_data_loader_n_workers": 1,
        "persistent_data_loader_workers": True,
        "mixed_precision": mixed_precision,
        "full_fp16": mixed_precision == "fp16" and full_precision,
        "full_bf16": mixed_precision == "bf16" and full_precision,
        "cache_latents": cache_latents,
        "cache_latents_to_disk": cache_latents_to_drive,
        "cache_text_encoder_outputs": cache_text_encoder_outputs,
        "min_timestep": 0,
        "max_timestep": 1000,
        "prior_loss_weight": 1.0,
        "multires_noise_iterations": 6 if multinoise else None,
        "multires_noise_discount": 0.3 if multinoise else None,
        "v_parameterization": vpred or None,
        "scale_v_pred_loss_like_noise_pred": vpred or None,
        "zero_terminal_snr": vpred or None,
      },
      "saving_arguments": {
        "save_precision": "fp16",
        "save_model_as": "safetensors",
        "save_every_n_epochs": save_every_n_epochs,
        "save_last_n_epochs": keep_only_last_n_epochs,
        "output_name": project_name,
        "output_dir": output_folder,
        "log_prefix": project_name,
        "logging_dir": log_folder,
        "wandb_api_key": wandb_key or None,
        "log_with": "wandb" if wandb_key else None,
      }
    }

    for key in config_dict:
      if isinstance(config_dict[key], dict):
        config_dict[key] = {k: v for k, v in config_dict[key].items() if v is not None}

    with open(config_file, "w") as f:
      f.write(toml.dumps(config_dict))
    print(f"\n📄 Config saved to {config_file}")

  if override_dataset_config_file:
    dataset_config_file = override_dataset_config_file
    print(f"⭕ Using custom dataset config file {dataset_config_file}")
  else:
    dataset_config_dict = {
      "general": {
        "resolution": resolution,
        "shuffle_caption": shuffle_caption and not cache_text_encoder_outputs,
        "keep_tokens": keep_tokens,
        "flip_aug": False,
        "caption_extension": caption_extension,
        "enable_bucket": True,
        "bucket_no_upscale": False,
        "bucket_reso_steps": bucket_reso_steps,
        "min_bucket_reso": min_bucket_reso,
        "max_bucket_reso": max_bucket_reso,
      },
      "datasets": toml.loads(custom_dataset)["datasets"] if custom_dataset else [
        {
          "subsets": [
            {
              "num_repeats": num_repeats,
              "image_dir": images_folder,
              "class_tokens": None if caption_extension else project_name
            }
          ]
        }
      ]
    }

    for key in dataset_config_dict:
      if isinstance(dataset_config_dict[key], dict):
        dataset_config_dict[key] = {k: v for k, v in dataset_config_dict[key].items() if v is not None}

    with open(dataset_config_file, "w") as f:
      f.write(toml.dumps(dataset_config_dict))
    print(f"📄 Dataset config saved to {dataset_config_file}")


def download_model():
  global old_model_url, model_url, model_file, vae_url, vae_file
  real_model_url = model_url  # There was a reason for having a separate variable but I forgot what it was.

  if real_model_url.startswith("/content/drive/"):
    # Local model, already checked to exist
    model_file = real_model_url
    print(f"📁 Using local model file: {model_file}")

    # Download VAE
    if not os.path.exists(vae_file):
      # !aria2c "{vae_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{vae_file}"

    # Validation
    if model_file.lower().endswith(".safetensors"):
      from safetensors.torch import load_file as load_safetensors
      try:
        test = load_safetensors(model_file)
        del test
      except:
        return False
    elif model_file.lower().endswith(".ckpt"):
      from torch import load as load_ckpt
      try:
        test = load_ckpt(model_file)
        del test
      except:
        return False
    return True

  else:
    # Downloadable model
    if load_diffusers:
      if 'huggingface.co' in real_model_url:
          match = re.search(r'huggingface\.co/([^/]+)/([^/]+)', real_model_url)
          if match:
              username = match.group(1)
              model_name = match.group(2)
              model_file = f"{username}/{model_name}"
              from huggingface_hub import HfFileSystem
              fs = HfFileSystem()
              existing_folders = set(fs.ls(model_file, detail=False))
              necessary_folders = [ "scheduler", "text_encoder", "text_encoder_2", "tokenizer", "tokenizer_2", "unet", "vae" ]
              if all(f"{model_file}/{folder}" in existing_folders for folder in necessary_folders):
                print("🍃 Diffusers model identified.")  # Will be handled by kohya
                return True
      raise ValueError("💥 Failed to load Diffusers model. If this model is not Diffusers, have you tried turning it off at the top of the colab?")

    # Define local filename
    if not model_file or old_model_url and old_model_url != model_url:
      if real_model_url.lower().endswith((".ckpt", ".safetensors")):
        model_file = f"/content{real_model_url[real_model_url.rfind('/'):]}"
      else:
        model_file = "/content/downloaded_model.safetensors"
        if os.path.exists(model_file):
          # !rm "{model_file}"

    # HuggingFace
    if m := re.search(r"(?:https?://)?(?:www\.)?huggingface\.co/[^/]+/[^/]+/blob", real_model_url):
      real_model_url = real_model_url.replace("blob", "resolve")
    # Civitai
    elif m := re.search(r"(?:https?://)?(?:www\\.)?civitai\.com/models/([0-9]+)(/[A-Za-z0-9-_]+)?", real_model_url):
      if m.group(2):
        model_file = f"/content{m.group(2)}.safetensors"
      if m := re.search(r"modelVersionId=([0-9]+)", real_model_url):
        real_model_url = f"https://civitai.com/api/download/models/{m.group(1)}"
      else:
        raise ValueError("💥 optional_custom_training_model contains a civitai link, but the link doesn't include a modelVersionId. You can also right click the download button to copy the direct download link.")

    # Download checkpoint
    # !aria2c "{real_model_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{model_file}"

    # Download VAE
    if not os.path.exists(vae_file):
      # !aria2c "{vae_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{vae_file}"

    # Validation

    if model_file.lower().endswith(".safetensors"):
      from safetensors.torch import load_file as load_safetensors
      try:
        test = load_safetensors(model_file)
        del test
      except:
        new_model_file = os.path.splitext(model_file)[0]+".ckpt"
        # !mv "{model_file}" "{new_model_file}"
        model_file = new_model_file
        print(f"Renamed model to {os.path.splitext(model_file)[0]}.ckpt")

    if model_file.lower().endswith(".ckpt"):
      from torch import load as load_ckpt
      try:
        test = load_ckpt(model_file)
        del test
      except:
        return False

  return True


def calculate_rex_steps():
  # https://github.com/derrian-distro/LoRA_Easy_Training_scripts_Backend/blob/c34084b0435e6e19bb7a01ac1ecbadd185ee8c1e/utils/validation.py#L268
  global max_train_steps
  return  # importing the BucketManager broke even though the transformers version is the same, idk
  print("\n🤔 Calculating Rex steps")
  if max_train_steps:
    calculated_max_steps = max_train_steps
  else:
    from library.train_util import BucketManager
    from PIL import Image
    from pathlib import Path
    import math

    with open(dataset_config_file, "r") as f:
      subsets = toml.load(f)["datasets"][0]["subsets"]

    supported_types = [".png", ".jpg", ".jpeg", ".webp", ".bmp"]
    res = (resolution, resolution)
    bucketManager = BucketManager(False, res, min_bucket_reso, max_bucket_reso, bucket_reso_steps)
    bucketManager.make_buckets()
    for subset in subsets:
        for image in Path(subset["image_dir"]).iterdir():
            if image.suffix not in supported_types:
                continue
            with Image.open(image) as img:
                bucket_reso, _, _ = bucketManager.select_bucket(img.width, img.height)
                for _ in range(subset["num_repeats"]):
                    bucketManager.add_image(bucket_reso, image)
    steps_before_acc = sum(math.ceil(len(bucket) / train_batch_size) for bucket in bucketManager.buckets)
    calculated_max_steps = math.ceil(steps_before_acc / gradient_accumulation_steps) * max_train_epochs
    del bucketManager

  cycle_steps = calculated_max_steps // (lr_scheduler_num_cycles or 1)
  print(f"  cycle steps: {cycle_steps}")
  lr_scheduler_args.append(f"first_cycle_max_steps={cycle_steps}")

  warmup_steps = round(calculated_max_steps * lr_warmup_ratio) // (lr_scheduler_num_cycles or 1)
  if warmup_steps > 0:
    print(f"  warmup steps: {warmup_steps}")
    lr_scheduler_args.append(f"warmup_steps={warmup_steps}")


def main():
  global dependencies_installed

  if not os.path.exists('/content/drive'):
    from google.colab import drive
    print("📂 Connecting to Google Drive...")
    drive.mount('/content/drive')

  for dir in (main_dir, trainer_dir, log_folder, images_folder, output_folder, config_folder):
    os.makedirs(dir, exist_ok=True)

  if not validate_dataset():
    return

  if not dependencies_installed:
    print("\n🏭 Installing trainer...\n")
    t0 = time()
    install_trainer()
    t1 = time()
    dependencies_installed = True
    print(f"\n✅ Installation finished in {int(t1-t0)} seconds.")
  else:
    print("\n✅ Dependencies already installed.")

  if old_model_url != model_url or not model_file or not os.path.exists(model_file):
    print("\n🔄 Getting model...")
    if not download_model():
      print("\n💥 Error: The model you specified is invalid or corrupted."
            "\nIf you're using an URL, please check that the model is accessible without being logged in."
            "\nYou can try civitai or huggingface URLs, or a path in your Google Drive starting with /content/drive/MyDrive")
      return
    print()
  else:
    print("\n🔄 Model already downloaded.\n")

  if lr_scheduler_type:
    create_config()
    os.chdir(kohya_dir)
    calculate_rex_steps()
    os.chdir(root_dir)

  create_config()

  print("\n⭐ Starting trainer...\n")

  os.chdir(kohya_dir)
  # !{venv_python} {train_network} --config_file={config_file} --dataset_config={dataset_config_file}
  os.chdir(root_dir)

  if not get_ipython().__dict__['user_ns']['_exit_code']:
    display(Markdown("### ✅ Done! [Go download your Lora from Google Drive](https://drive.google.com/drive/my-drive)\n"
                     "### There will be several files, you should try the latest version (the file with the largest number next to it)"))

main()
# Out:
# 💿 Checking dataset...
# 📁MyDrive/fsces
# 📈 Found 1561 images with 1 repeats, equaling 1561 steps.
# 📉 Divide 1561 steps by 3 batch size to get 520.3333333333334 steps per epoch.
# 🔮 There will be 10 epochs, for around 5203 total training steps.
#
# ✅ Dependencies already installed.
#
# 🔄 Model already downloaded.
#
#
# 📄 Config saved to /content/drive/MyDrive/lora_training/config/zazi/training_config.toml
# 📄 Dataset config saved to /content/drive/MyDrive/lora_training/config/zazi/dataset_config.toml
#
# ⭐ Starting trainer...
#
# rich is not installed, using basic logging
# Loading settings from /content/drive/MyDrive/lora_training/config/zazi/training_config.toml...
# /content/drive/MyDrive/lora_training/config/zazi/training_config
# rich is not installed, using basic logging
# Loading dataset config from /content/drive/MyDrive/lora_training/config/zazi/dataset_config.toml
# prepare images.
# get image size from name of cache files
# 100% 1561/1561 [00:00<00:00, 665512.15it/s]
# set image size from cache files: 0/1561
# found directory /content/drive/MyDrive/fsces contains 1561 image files
# read caption:   0% 0/1561 [00:00<?, ?it/s]neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0000.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0000.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0001.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0001.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0002.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0002.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0003.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0003.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0004.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0004.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0005.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0005.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0006.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0006.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0007.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0007.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0008.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0008.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0009.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0009.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0010.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0010.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0011.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0011.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0012.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0012.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0013.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0013.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0014.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0014.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0015.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0015.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0016.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0016.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0017.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0017.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0018.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0018.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0019.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0019.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0020.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0020.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0021.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0021.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0022.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0022.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0023.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0023.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0024.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0024.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0025.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0025.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0026.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0026.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0027.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0027.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0028.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0028.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0029.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0029.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0030.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0030.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0031.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0031.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0032.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0032.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0033.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0033.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0034.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0034.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0035.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0035.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0036.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0036.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0037.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0037.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0038.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0038.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0039.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0039.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0040.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0040.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0041.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0041.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0042.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0042.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0043.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0043.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0044.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0044.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0045.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0045.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0046.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0046.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0047.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0047.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0048.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0048.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0049.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0049.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0050.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0050.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0051.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0051.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0052.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0052.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0053.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0053.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0054.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0054.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0055.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0055.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0056.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0056.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0057.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0057.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0058.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0058.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0059.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0059.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0060.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0060.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0061.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0061.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0062.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0062.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0063.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0063.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0064.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0064.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0065.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0065.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0066.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0066.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0067.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0067.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0068.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0068.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0069.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0069.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0070.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0070.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0071.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0071.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0072.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0072.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0073.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0073.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0074.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0074.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0075.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0075.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0076.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0076.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0077.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0077.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0078.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0078.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0079.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0079.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0080.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0080.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0081.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0081.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0082.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0082.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0083.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0083.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0084.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0084.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0085.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0085.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0086.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0086.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0087.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0087.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0088.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0088.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0089.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0089.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0090.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0090.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0091.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0091.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0092.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0092.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0093.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0093.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0094.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0094.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0095.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0095.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0096.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0096.png
# read caption:   6% 97/1561 [00:00<00:01, 967.63it/s]neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0097.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0097.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0098.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0098.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0099.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0099.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0100.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0100.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0101.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0101.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0102.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0102.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0103.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0103.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0104.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0104.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0105.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0105.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0106.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0106.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0107.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0107.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0108.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0108.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0109.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0109.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0110.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0110.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0111.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0111.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0112.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0112.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0113.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0113.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0114.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0114.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0115.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0115.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0116.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0116.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0117.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0117.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0118.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0118.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0119.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0119.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0120.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0120.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0121.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0121.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0122.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0122.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0123.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0123.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0124.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0124.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0125.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0125.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0126.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0126.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_
# accelerator device: cuda
# loading model for process 0/1
# load StableDiffusion checkpoint: /content/sd_xl_base_1.0.safetensors
# building U-Net
# loading U-Net from checkpoint
# U-Net: <All keys matched successfully>
# building text encoders
# loading text encoders from checkpoint
# text encoder 1: <All keys matched successfully>
# text encoder 2: <All keys matched successfully>
# building VAE
# loading VAE from checkpoint
# VAE: <All keys matched successfully>
# load VAE:
# exception occurs in loading vae: We couldn't connect to 'https://huggingface.co' to load this model, couldn't find it in the cached files and it looks like  is not the path to a directory containing a config.json file.
# Checkout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/diffusers/installation#offline-mode'.
# retry with subfolder='vae'
# Traceback (most recent call last):
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/configuration_utils.py", line 376, in load_config
#     config_file = hf_hub_download(
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py", line 101, in inner_f
#     return f(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 106, in _inner_fn
#     validate_repo_id(arg_value)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 160, in validate_repo_id
#     raise HFValidationError(
# huggingface_hub.errors.HFValidationError: Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are forbidden, '-' and '.' cannot start or end the name, max length is 96: ''.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/trainer/sd_scripts/library/model_util.py", line 1272, in load_vae
#     vae = AutoencoderKL.from_pretrained(vae_id, subfolder=None, torch_dtype=dtype)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/models/modeling_utils.py", line 712, in from_pretrained
#     config, unused_kwargs, commit_hash = cls.load_config(
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/configuration_utils.py", line 411, in load_config
#     raise EnvironmentError(
# OSError: We couldn't connect to 'https://huggingface.co' to load this model, couldn't find it in the cached files and it looks like  is not the path to a directory containing a config.json file.
# Checkout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/diffusers/installation#offline-mode'.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/configuration_utils.py", line 376, in load_config
#     config_file = hf_hub_download(
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py", line 101, in inner_f
#     return f(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 106, in _inner_fn
#     validate_repo_id(arg_value)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 160, in validate_repo_id
#     raise HFValidationError(
# huggingface_hub.errors.HFValidationError: Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are forbidden, '-' and '.' cannot start or end the name, max length is 96: ''.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/trainer/sd_scripts/sdxl_train_network.py", line 228, in <module>
#     trainer.train(args)
#   File "/content/trainer/sd_scripts/train_network.py", line 413, in train
#     model_version, text_encoder, vae, unet = self.load_target_model(args, weight_dtype, accelerator)
#   File "/content/trainer/sd_scripts/sdxl_train_network.py", line 50, in load_target_model
#     ) = sdxl_train_util.load_target_model(args, accelerator, sdxl_model_util.MODEL_VERSION_SDXL_BASE_V1_0, weight_dtype)
#   File "/content/trainer/sd_scripts/library/sdxl_train_util.py", line 42, in load_target_model
#     ) = _load_target_model(
#   File "/content/trainer/sd_scripts/library/sdxl_train_util.py", line 130, in _load_target_model
#     vae = model_util.load_vae(vae_path, weight_dtype)
#   File "/content/trainer/sd_scripts/library/model_util.py", line 1276, in load_vae
#     vae = AutoencoderKL.from_pretrained(vae_id, subfolder="vae", torch_dtype=dtype)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/models/modeling_utils.py", line 712, in from_pretrained
#     config, unused_kwargs, commit_hash = cls.load_config(
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/configuration_utils.py", line 411, in load_config
#     raise EnvironmentError(
# OSError: We couldn't connect to 'https://huggingface.co' to load this model, couldn't find it in the cached files and it looks like  is not the path to a directory containing a config.json file.
# Checkout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/diffusers/installation#offline-mode'.

# %% [markdown]
# ## *️⃣ Extras
#
# You can run these before starting the training.

# %% [markdown]
# ### 📚 Multiple folders in dataset
# Below is a template allowing you to define multiple folders in your dataset. You must include the location of each folder and you can set different number of repeats for each one. To add more folders simply copy and paste the sections starting with `[[datasets.subsets]]`.
#
# When enabling this, the number of repeats set in the main cell will be ignored, and the main folder set by the project name will also be ignored.
#
# You can make one of them a regularization folder by adding `is_reg = true`
# You can also set different `keep_tokens`, `flip_aug`, etc.

# %%
custom_dataset = """
[[datasets]]
resolution = 1024
batch_size = 1

  [[datasets.subsets]]
  image_dir =  "/content/drive/MyDrive/fsces"
  num_repeats = 1
"""

# %%
# !pip install codecarbon -q

from codecarbon import EmissionsTracker
import psutil, torch

tracker = EmissionsTracker(
    project_name="SDXL_LoRA_Training",
    measure_power_secs=10,
    log_level="error"
)
tracker.start()

if torch.cuda.is_available():
    gpu_name  = torch.cuda.get_device_name(0)
    gpu_mem   = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"GPU:        {gpu_name}")
    print(f"VRAM:       {gpu_mem:.1f} GB")

ram = psutil.virtual_memory()
print(f"RAM:        {ram.total / 1e9:.1f} GB total")
print("Tracking started...")

# %%
emissions = tracker.stop()

print("=" * 40)
print("     ENERGY USAGE REPORT")
print("=" * 40)
print(f"Energy:      {tracker._total_energy.kWh:.4f} kWh")
print(f"CO2:         {emissions * 1000:.2f} grams")
print(f"km driven:   {emissions * 1000 / 21:.4f} km")
print("=" * 40)

# %%
import os

print("MyDrive root:")
print(os.listdir("/content/drive/MyDrive/fsces"))
# Out:
# MyDrive root:
733.png', 'face_0736.png', 'face_0738.png', 'face_0735.png', 'face_0737.png', 'face_0739.png', 'face_0741.png', 'face_0740.png', 'face_0742.png', 'face_0744.png', 'face_0743.png', 'face_0745.png', 'face_0748.png', 'face_0747.png', 'face_0746.png', 'face_0749.png', 'face_0751.png', 'face_0750.png', 'face_0754.png', 'face_0755.png', 'face_0752.png', 'face_0753.png', 'face_0756.png', 'face_0759.png', 'face_0758.png', 'face_0757.png', 'face_0761.png', 'face_0762.png', 'face_0760.png', 'face_0763.png', 'face_0764.png', 'face_0766.png', 'face_0767.png', 'face_0765.png', 'face_0769.png', 'face_0770.png', 'face_0768.png', 'face_0771.png', 'face_0772.png', 'face_0773.png', 'face_0775.png', 'face_0774.png', 'face_0776.png', 'face_0777.png', 'face_0778.png', 'face_0781.png', 'face_0779.png', 'face_0780.png', 'face_0783.png', 'face_0784.png', 'face_0785.png', 'face_0782.png', 'face_0788.png', 'face_0786.png', 'face_0787.png', 'face_0789.png', 'face_0790.png', 'face_0791.png', 'face_0792.png', 'face_0793.png', 'face_0796.png', 'face_0794.png', 'face_0795.png', 'fac ...

# %%
#@markdown ### 📂 Unzip dataset
#@markdown It's much slower to upload individual files to your Drive, so you may want to upload a zip if you have your dataset in your computer.
zip = "/content/drive/MyDrive/my_dataset.zip" #@param {type:"string"}
extract_to = "/content/drive/MyDrive/Loras/example/dataset" #@param {type:"string"}

import os, zipfile

if not os.path.exists('/content/drive'):
  from google.colab import drive
  print("📂 Connecting to Google Drive...")
  drive.mount('/content/drive')

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip, 'r') as f:
  f.extractall(extract_to)

print("✅ Done")

# %%
#@markdown ### 🔢 Count datasets
#@markdown Google Drive makes it impossible to count the files in a folder, so this will show you the file counts in all folders and subfolders.
folder = "/content/drive/MyDrive/Loras" #@param {type:"string"}

import os
from google.colab import drive

if not os.path.exists('/content/drive'):
    print("📂 Connecting to Google Drive...\n")
    drive.mount('/content/drive')

tree = {}
exclude = ("_logs", "/output")
for i, (root, dirs, files) in enumerate(os.walk(folder, topdown=True)):
  dirs[:] = [d for d in dirs if all(ex not in d for ex in exclude)]
  images = len([f for f in files if f.lower().endswith((".png", ".jpg", ".jpeg"))])
  captions = len([f for f in files if f.lower().endswith(".txt")])
  others = len(files) - images - captions
  path = root[folder.rfind("/")+1:]
  tree[path] = None if not images else f"{images:>4} images | {captions:>4} captions |"
  if tree[path] and others:
    tree[path] += f" {others:>4} other files"

pad = max(len(k) for k in tree)
print("\n".join(f"📁{k.ljust(pad)} | {v}" for k, v in tree.items() if v))

# %%
#@markdown ### ↪️ Continue

#@markdown Here you can write a path in your Google Drive to load an existing Lora file to continue training on.<p>
#@markdown **Warning:** It's not the same as one long training session. The epochs start from scratch, and it may have worse results.
continue_from_lora = "" #@param {type:"string"}
if continue_from_lora and not continue_from_lora.startswith("/content/drive/MyDrive"):
  import os
  continue_from_lora = os.path.join("/content/drive/MyDrive", continue_from_lora)

# %% [markdown]
# # 📈 Plot training results
# You can do this after running the trainer. You don't need this unless you know what you're doing.
# The first cell below may fail to load all your logs. Keep trying the second cell until all data has loaded.

# %%
# %load_ext tensorboard
# %tensorboard --logdir={log_folder}/

# %%
from tensorboard import notebook
notebook.display(port=6006, height=800)

# %% [markdown]
# # Task
# Explicitly download the Stable Diffusion XL VAE model to `/content/sdxl_vae.safetensors` and then re-run the main setup cell (`OglZzI_ujZq-`) to initiate the training process.

# %% [markdown]
# ## Set VAE Model Details
#
# ### Subtask:
# Modify the notebook to set the `vae_url` and `vae_file` variables to the correct values for the Stable Diffusion XL VAE model. This will ensure the VAE is properly identified for download and use.

# %% [markdown]
# **Reasoning**:
# The subtask requires modifying the `vae_url` and `vae_file` variables to specify the correct path for the Stable Diffusion XL VAE model. I will add a code block to explicitly set these variables.

# %%
import os
import re
import toml
from time import time
from IPython.display import Markdown, display
import warnings

warnings.filterwarnings("ignore")

# These carry information from past executions
if "model_url" in globals():
  old_model_url = model_url
else:
  old_model_url = None
if "dependencies_installed" not in globals():
  dependencies_installed = False
if "model_file" not in globals():
  model_file = None

# These may be set by other cells, some are legacy
if "custom_dataset" not in globals():
  custom_dataset = None
if "override_dataset_config_file" not in globals():
  override_dataset_config_file = None
if "continue_from_lora" not in globals():
  continue_from_lora = ""
if "override_config_file" not in globals():
  override_config_file = None

#try:
#  LOWRAM = int(next(line.split()[1] for line in open('/proc/meminfo') if "MemTotal" in line)) / (1024**2) < 15
#except:
#  LOWRAM = True

COMMIT = "47ef6ed843ee1951cd07838c5fdcca60c954130c"
LOWRAM = True
LOAD_TRUNCATED_IMAGES = True
BETTER_EPOCH_NAMES = True
FIX_DIFFUSERS = True


#@title ## 🚩 Start Here

#@markdown ### ▶️ Setup
#@markdown Your project name will be the same as the folder containing your images. Spaces aren't allowed.
project_name = "zazi" #@param {type:"string"}
project_name = project_name.strip()
#@markdown The folder structure doesn't matter and is purely for comfort. Make sure to always pick the same one. I like organizing by project.
folder_structure = "Organize by category (MyDrive/lora_training/datasets/project_name)" #@param ["Organize by category (MyDrive/lora_training/datasets/project_name)", "Organize by project (MyDrive/Loras/project_name/dataset)"]
#@markdown Decide the model that will be downloaded and used for training. You can also choose your own by pasting its download link, or a file in your Google Drive starting with `/content/drive/MyDrive`.
training_model = "Stable Diffusion XL 1.0 base" #@param ["Pony Diffusion V6 XL", "Illustrious XL 0.1", "NoobAI V-Pred 1.0", "NoobAI Eps 1.1", "Animagine XL V3", "Stable Diffusion XL 1.0 base"]
optional_custom_training_model = "" #@param {type:"string"}
custom_model_is_diffusers = False #@param {type:"boolean"}
custom_model_is_vpred = False #@param {type:"boolean"}

load_diffusers = custom_model_is_diffusers and len(optional_custom_training_model) > 0
vpred = custom_model_is_vpred and len(optional_custom_training_model) > 0

if optional_custom_training_model:
  model_url = optional_custom_training_model
elif "Pony" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/hollowstrawberry/67AB2F"
  else:
    model_url = "https://civitai.com/api/download/models/290640"
    model_file = "/content/ponyDiffusionV6XL.safetensors"
elif "Animagine" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/cagliostrolab/animagine-xl-3.0"
  else:
    model_url = "https://civitai.com/api/download/models/293564"
    model_file = "/content/animagineXLV3.safetensors"
elif "Illustrious" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/OnomaAIResearch/Illustrious-xl-early-release-v0"
  else:
    model_url = "https://huggingface.co/OnomaAIResearch/Illustrious-xl-early-release-v0/resolve/main/Illustrious-XL-v0.1.safetensors"
elif "NoobAI Eps" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-1.1"
  else:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-1.1/resolve/main/NoobAI-XL-v1.1.safetensors"
elif "NoobAI V-Pred" in training_model:
  vpred = True
  if load_diffusers:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-Vpred-1.0"
  else:
    model_url = "https://huggingface.co/Laxhar/noobai-XL-Vpred-1.0/resolve/main/NoobAI-XL-Vpred-v1.0.safetensors"
else:
  if load_diffusers:
    model_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0"
  else:
    model_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors"

if load_diffusers:
  vae_file = ""
else:
  vae_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_vae.safetensors"
  vae_file = "/content/sdxl_vae.safetensors"

model_url = model_url.strip()

#@markdown ### ▶️ Processing
resolution = 1024 #param {type:"slider", min:768, max:1536, step:128}
caption_extension = ".txt" #@param [".txt", ".caption"]
#@markdown Shuffling anime tags in place improves learning and prompting. An activation tag goes at the start of every text file and will not be shuffled.<p>
shuffle_tags = True #@param {type:"boolean"}
shuffle_caption = shuffle_tags
activation_tags = "1" #@param [0,1,2,3]
keep_tokens = int(activation_tags)

#@markdown ### ▶️ Steps <p>
#@markdown Your images will repeat this number of times during training. I recommend that your images multiplied by their repeats is around 100, or 1 repeat with more than 100 images.
num_repeats = 2 #@param {type:"number"}
#@markdown Choose how long you want to train for. A good starting point is around 10 epochs or around 2000 steps.<p>
#@markdown One epoch is a number of steps equal to: your number of images multiplied by their repeats, divided by batch size. <p>
preferred_unit = "Epochs" #@param ["Epochs", "Steps"]
how_many = 10 #@param {type:"number"}
max_train_epochs = how_many if preferred_unit == "Epochs" else None
max_train_steps = how_many if preferred_unit == "Steps" else None
#@markdown Saving more epochs will let you compare your Lora's progress better.
save_every_n_epochs = 1 #@param {type:"number"}
keep_only_last_n_epochs = 10 #@param {type:"number"}
if not save_every_n_epochs:
  save_every_n_epochs = max_train_epochs
if not keep_only_last_n_epochs:
  keep_only_last_n_epochs = max_train_epochs

#@markdown ### ▶️ Learning
#@markdown The learning rate is the most important for your results. If your Lora produces black images, lower the unet and text encoder to 1e-4 and 1e-5 respectively, or even lower. <p>
#@markdown If you're training a style you can choose to set the text encoder to 0.
unet_lr = 1e-4 #@param {type:"number"}
text_encoder_lr = 5e-5 #@param {type:"number"}
#@markdown The scheduler is the algorithm that guides the learning rate. If you're not sure, pick `constant` and ignore the number. I personally recommend `cosine_with_restarts` with 3 restarts.
lr_scheduler = "cosine_with_restarts" #@param ["constant", "cosine", "cosine_with_restarts", "constant_with_warmup", "linear", "polynomial", "rex"]
lr_scheduler_number = 3 #@param {type:"number"}
#@markdown Steps spent "warming up" the learning rate during training for efficiency. I recommend leaving it at 5%.
lr_warmup_ratio = 0.05 #@param {type:"slider", min:0.0, max:0.2, step:0.01}
lr_warmup_steps = 0
#@markdown These settings may produce better results. min_snr_gamma adjusts loss over time. ip_noise_gamma adjusts random noise.
min_snr_gamma_enabled = True #@param {type:"boolean"}
min_snr_gamma = 8.0 #@param {type:"slider", min:4, max:16.0, step:0.5}
ip_noise_gamma_enabled = False #@param {type:"boolean"}
ip_noise_gamma = 0.05 #@param {type:"slider", min:0.05, max:0.1, step:0.01}
#@markdown Multinoise may help with color balance (darker darks, lighter lights).
multinoise = True #@param {type:"boolean"}

#@markdown ### ▶️ Structure
#@markdown LoRA is the classic type and good for a variety of purposes. LoCon is good with artstyles as it has more layers to learn more aspects of the dataset.
lora_type = "LoRA" #@param ["LoRA", "LoCon"]

#@markdown Below are some recommended XL values for the following settings:

#@markdown | type | network_dim | network_alpha | conv_dim | conv_alpha |
#@markdown | :---: | :---: | :---: | :---: | :---: |
#@markdown | Regular LoRA | 8 | 4 |   |   |
#@markdown | Style LoCon | 16 | 8 | 16 | 8 |

#@markdown More dim means larger Lora, it can hold more information but more isn't always better.
network_dim = 8 #@param {type:"slider", min:1, max:32, step:1}
network_alpha = 4 #@param {type:"slider", min:1, max:32, step:1}
#@markdown The following two values only apply to the additional layers of LoCon.
conv_dim = 16 #@param {type:"slider", min:1, max:32, step:1}
conv_alpha = 8 #@param {type:"slider", min:1, max:32, step:1}

network_module = "networks.lora"
network_args = None
if lora_type.lower() == "locon":
  network_args = [f"conv_dim={conv_dim}", f"conv_alpha={conv_alpha}"]

#@markdown ### ▶️ Training
#@markdown Adjust these parameters depending on your colab configuration.
#@markdown
#@markdown Higher batch size is often faster but uses more memory.
train_batch_size = 3 #@param {type:"slider", min:1, max:16, step:1}
#@markdown I have found no substantial difference between sdpa and xformers.
cross_attention = "sdpa" #@param ["sdpa", "xformers"]
#@markdown Use `full fp16` for lowest memory usage. The `bf16` options may not work correctly on the free GPU tier.<p>
#@markdown The Lora will be trained with the selected precision, but will always be saved in fp16 format for compatibility reasons.
precision = "full fp16" #@param ["float", "full fp16", "full bf16", "mixed fp16", "mixed bf16"]
#@markdown Caching latents to drive will add a 250KB file next to each image but will use considerably less memory.
cache_latents = True #@param {type:"boolean"}
cache_latents_to_drive = True #@param {type:"boolean"}
#@markdown The following option will turn off shuffle_tags and disable text encoder training.
cache_text_encoder_outputs  = False  # @param {type:"boolean"}

mixed_precision = "no"
if "fp16" in precision:
  mixed_precision = "fp16"
elif "bf16" in precision:
  mixed_precision = "bf16"
full_precision = "full" in precision

#@markdown ### ▶️ Advanced
#@markdown The optimizer is the algorithm used for training. AdamW8bit is the default and works great, while Prodigy manages learning rate automatically and may have several advantages such as training faster due to needing less steps as well as working better for small datasets.
optimizer = "AdamW8bit" #@param ["AdamW8bit", "Prodigy", "DAdaptation", "DadaptAdam", "DadaptLion", "AdamW", "Lion", "SGDNesterov", "SGDNesterov8bit", "AdaFactor", "Came"]
#@markdown Recommended args for AdamW8bit: `weight_decay=0.1 betas=[0.9,0.99]`<p>
#@markdown Recommended args for Prodigy: `decouple=True weight_decay=0.01 betas=[0.9,0.999] d_coef=2 use_bias_correction=True safeguard_warmup=True`<p>
#@markdown Recommended args for AdaFactor: `scale_parameter=False relative_step=False warmup_init=False`<p>
#@markdown Recommended args for Came: `weight_decay=0.04`<p>
#@markdown If Dadapt or Prodigy are selected and the recommended box is checked, the following values will override any previous settings:<p>
#@markdown `unet_lr=0.75`, `text_encoder_lr=0.75`, `network_alpha=network_dim`, `full_precision=False`<p>
recommended_values = True #@param {type:"boolean"}
#@markdown Alternatively set your own optimizer arguments separated by spaces (not commas). Recommended box must be disabled.
optimizer_args = "" #@param {type:"string"}
optimizer_args = [a.strip() for a in optimizer_args.split(' ') if a]

if recommended_values:
  if any(opt in optimizer.lower() for opt in ["dadapt", "prodigy"]):
    unet_lr = 0.75
    text_encoder_lr = 0.75
    network_alpha = network_dim
    full_precision = False
  if optimizer == "Prodigy":
    optimizer_args = ["decouple=True", "weight_decay=0.01", "betas=[0.9,0.999]", "d_coef=2", "use_bias_correction=True", "safeguard_warmup=True"]
  elif optimizer == "AdamW8bit":
    optimizer_args = ["weight_decay=0.1", "betas=[0.9,0.99]"]
  elif optimizer == "AdaFactor":
    optimizer_args = ["scale_parameter=False", "relative_step=False", "warmup_init=False"]
  elif optimizer == "Came":
    optimizer_args = ["weight_decay=0.04"]

if optimizer == "Came":
  optimizer = "LoraEasyCustomOptimizer.came.CAME"

lr_scheduler_type = None
lr_scheduler_args = None
lr_scheduler_num_cycles = lr_scheduler_number
lr_scheduler_power = lr_scheduler_number

if "rex" in lr_scheduler:
  lr_scheduler = "cosine"
  lr_scheduler_type = "LoraEasyCustomOptimizer.RexAnnealingWarmRestarts.RexAnnealingWarmRestarts"
  lr_scheduler_args = ["min_lr=1e-9", "gamma=0.9", "d=0.9"]

# Misc
seed = 42
gradient_accumulation_steps = 1
bucket_reso_steps = 64
min_bucket_reso = 256
max_bucket_reso = 4096


#@markdown ### ▶️ Ready
#@markdown You can now run this cell to cook your Lora. Good luck! <p>


# 👩‍💻 Cool code goes here

root_dir = "/content"
trainer_dir = os.path.join(root_dir, "trainer")
kohya_dir = os.path.join(trainer_dir, "sd_scripts")

venv_python = os.path.join(kohya_dir, "venv/bin/python")
venv_pip = os.path.join(kohya_dir, "venv/bin/pip")
train_network = os.path.join(kohya_dir, "sdxl_train_network.py")

if "/Loras" in folder_structure:
  main_dir      = os.path.join(root_dir, "drive/MyDrive/Loras")
  log_folder    = os.path.join(main_dir, "_logs")
  config_folder = os.path.join(main_dir, project_name)
  images_folder = os.path.join(main_dir, project_name, "dataset")
  output_folder = os.path.join(main_dir, project_name, "output")
else:
  main_dir      = os.path.join(root_dir, "drive/MyDrive/lora_training")
  images_folder = os.path.join(main_dir, "datasets", project_name)
  output_folder = os.path.join(main_dir, "output", project_name)
  config_folder = os.path.join(main_dir, "config", project_name)
  log_folder    = os.path.join(main_dir, "log")

config_file = os.path.join(config_folder, "training_config.toml")
dataset_config_file = os.path.join(config_folder, "dataset_config.toml")


def install_trainer():
  # !apt -y update -qq
  # !apt install -y python3.10-venv aria2 -qq
  # !git clone https://github.com/derrian-distro/LoRA_Easy_Training_scripts_Backend {trainer_dir}
  os.chdir(trainer_dir)
  # !git reset --hard {COMMIT}
  # !chmod 755 ./colab_install.sh
  # !./colab_install.sh

  # fix logging
  # !{venv_pip} uninstall -y rich

  # patch kohya
  os.chdir(kohya_dir)
  if LOAD_TRUNCATED_IMAGES:
    # !sed -i 's/from PIL import Image/from PIL import Image, ImageFile\nImageFile.LOAD_TRUNCATED_IMAGES=True/g' library/train_util.py # fix truncated jpegs error
  if BETTER_EPOCH_NAMES:
    # !sed -i 's/{:06d}/{:02d}/g' library/train_util.py # make epoch names shorter
    # !sed -i 's/\".\" + args.save_model_as)/\"-{:02d}.\".format(num_train_epochs) + args.save_model_as)/g' train_network.py # name of the last epoch will match the rest
  if FIX_DIFFUSERS:
    deprecation_utils = os.path.join(kohya_dir, "venv/lib/python3.10/site-packages/diffusers/utils/deprecation_utils.py")
    # !sed -i 's/if version.parse/if False:#/g' {deprecation_utils}
  if wandb_key:
    # !sed -i 's/accelerator.log(logs, step=epoch + 1)//g' train_network.py  # fix warning
    # !sed -i 's/accelerator.log(logs, step=epoch + 1)//g' sdxl_train.py  # fix warning

  os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
  os.environ["BITSANDBYTES_NOWELCOME"] = "1"
  os.environ["SAFETENSORS_FAST_GPU"] = "1"
  os.environ["PYTHONWARNINGS"] = "ignore"
  os.chdir(root_dir)


def validate_dataset():
  global lr_warmup_steps, lr_warmup_ratio, caption_extension, keep_tokens, model_url
  supported_types = (".png", ".jpg", ".jpeg", ".webp", ".bmp")

  if model_url.startswith("/content/drive/") and not os.path.exists(model_url):
    print("💥 Error: The custom training model you specified was not found in your Google Drive.")
    return

  print("\n💿 Checking dataset...")
  if not project_name.strip() or any(c in project_name for c in " .()\"'\/"):
    print("💥 Error: Please choose a valid project name.")
    return

  # Find the folders and files
  if custom_dataset:
    try:
      datconf = toml.loads(custom_dataset)
      datasets = [d for d in datconf["datasets"][0]["subsets"]]
    except:
      print(f"💥 Error: Your custom dataset is invalid or contains an error! Please check the original template.")
      return
    reg = [d.get("image_dir") for d in datasets if d.get("is_reg", False)]
    datasets_dict = {d["image_dir"]: d["num_repeats"] for d in datasets}
    folders = datasets_dict.keys()
    files = [f for folder in folders for f in os.listdir(folder)]
    images_repeats = {folder: (len([f for f in os.listdir(folder) if f.lower().endswith(supported_types)]), datasets_dict[folder]) for folder in folders}
  else:
    reg = []
    folders = [images_folder]
    files = os.listdir(images_folder)
    images_repeats = {images_folder: (len([f for f in files if f.lower().endswith(supported_types)]), num_repeats)}

  # Validation
  for folder in folders:
    if not os.path.exists(folder):
      print(f"💥 Error: The folder {folder.replace('/content/drive/', '')} doesn't exist.")
      return
  for folder, (img, rep) in images_repeats.items():
    if not img:
      print(f"💥 Error: Your {folder.replace('/content/drive/', '')} folder is empty.")
      return
  test_files = []
  for f in files:
    if not f.lower().endswith((caption_extension, ".npz")) and not f.lower().endswith(supported_types):
      print(f"💥 Error: Invalid file in dataset: \"{f}\". Aborting.")
      return
    for ff in test_files:
      if f.endswith(supported_types) and ff.endswith(supported_types) \
          and os.path.splitext(f)[0] == os.path.splitext(ff)[0]:
        print(f"💥 Error: The files {f} and {ff} cannot have the same name. Aborting.")
        return
    test_files.append(f)

  if caption_extension and not [txt for txt in files if txt.lower().endswith(caption_extension)]:
    caption_extension = ""
  if continue_from_lora and not (continue_from_lora.endswith(".safetensors") and os.path.exists(continue_from_lora)):
    print(f"💥 Error: Invalid path to existing Lora. Example: /content/drive/MyDrive/Loras/example.safetensors")
    return

  # Show estimations to the user

  pre_steps_per_epoch = sum(img*rep for (img, rep) in images_repeats.values())
  steps_per_epoch = pre_steps_per_epoch/train_batch_size
  total_steps = max_train_steps or int(max_train_epochs*steps_per_epoch)
  estimated_epochs = int(total_steps/steps_per_epoch)
  lr_warmup_steps = int(total_steps*lr_warmup_ratio)

  for folder, (img, rep) in images_repeats.items():
    print("📁"+folder.replace("/content/drive/", "") + (" (Regularization)" if folder in reg else ""))
    print(f"📈 Found {img} images with {rep} repeats, equaling {img*rep} steps.")
  print(f"📉 Divide {pre_steps_per_epoch} steps by {train_batch_size} batch size to get {steps_per_epoch} steps per epoch.")
  if max_train_epochs:
    print(f"🔮 There will be {max_train_epochs} epochs, for around {total_steps} total training steps.")
  else:
    print(f"🔮 There will be {total_steps} steps, divided into {estimated_epochs} epochs and then some.")

  if total_steps > 10000:
    print("💥 Error: Your total steps are too high. You probably made a mistake. Aborting...")
    return

  return True


def create_config():
  global dataset_config_file, config_file, model_file

  if override_config_file:
    config_file = override_config_file
    print(f"\n⭕ Using custom config file {config_file}")
  else:
    config_dict = {
      "network_arguments": {
        "unet_lr": unet_lr,
        "text_encoder_lr": text_encoder_lr if not cache_text_encoder_outputs else 0,
        "network_dim": network_dim,
        "network_alpha": network_alpha,
        "network_module": network_module,
        "network_args": network_args,
        "network_train_unet_only": text_encoder_lr == 0 or cache_text_encoder_outputs,
        "network_weights": continue_from_lora or None
      },
      "optimizer_arguments": {
        "learning_rate": unet_lr,
        "lr_scheduler": lr_scheduler,
        "lr_scheduler_type": lr_scheduler_type,
        "lr_scheduler_args": lr_scheduler_args,
        "lr_scheduler_num_cycles": lr_scheduler_num_cycles if lr_scheduler == "cosine_with_restarts" else None,
        "lr_scheduler_power": lr_scheduler_power if lr_scheduler == "polynomial" else None,
        "lr_warmup_steps": lr_warmup_steps if lr_scheduler not in ("cosine", "constant") else None,
        "optimizer_type": optimizer,
        "optimizer_args": optimizer_args or None,
        "loss_type": "l2",
        "max_grad_norm": 1.0,
      },
      "training_arguments": {
        "lowram": LOWRAM,
        "pretrained_model_name_or_path": model_file,
        "vae": vae_file,
        "max_train_steps": max_train_steps,
        "max_train_epochs": max_train_epochs,
        "train_batch_size": train_batch_size,
        "seed": seed,
        "max_token_length": 225,
        "xformers": cross_attention == "xformers",
        "sdpa": cross_attention == "sdpa",
        "min_snr_gamma": min_snr_gamma if min_snr_gamma_enabled else None,
        "ip_noise_gamma": ip_noise_gamma if ip_noise_gamma_enabled else None,
        "no_half_vae": True,
        "gradient_checkpointing": True,
        "gradient_accumulation_steps": gradient_accumulation_steps,
        "max_data_loader_n_workers": 1,
        "persistent_data_loader_workers": True,
        "mixed_precision": mixed_precision,
        "full_fp16": mixed_precision == "fp16" and full_precision,
        "full_bf16": mixed_precision == "bf16" and full_precision,
        "cache_latents": cache_latents,
        "cache_latents_to_disk": cache_latents_to_drive,
        "cache_text_encoder_outputs": cache_text_encoder_outputs,
        "min_timestep": 0,
        "max_timestep": 1000,
        "prior_loss_weight": 1.0,
        "multires_noise_iterations": 6 if multinoise else None,
        "multires_noise_discount": 0.3 if multinoise else None,
        "v_parameterization": vpred or None,
        "scale_v_pred_loss_like_noise_pred": vpred or None,
        "zero_terminal_snr": vpred or None,
      },
      "saving_arguments": {
        "save_precision": "fp16",
        "save_model_as": "safetensors",
        "save_every_n_epochs": save_every_n_epochs,
        "save_last_n_epochs": keep_only_last_n_epochs,
        "output_name": project_name,
        "output_dir": output_folder,
        "log_prefix": project_name,
        "logging_dir": log_folder,
        "wandb_api_key": wandb_key or None,
        "log_with": "wandb" if wandb_key else None,
      }
    }

    for key in config_dict:
      if isinstance(config_dict[key], dict):
        config_dict[key] = {k: v for k, v in config_dict[key].items() if v is not None}

    with open(config_file, "w") as f:
      f.write(toml.dumps(config_dict))
    print(f"\n📄 Config saved to {config_file}")

  if override_dataset_config_file:
    dataset_config_file = override_dataset_config_file
    print(f"⭕ Using custom dataset config file {dataset_config_file}")
  else:
    dataset_config_dict = {
      "general": {
        "resolution": resolution,
        "shuffle_caption": shuffle_caption and not cache_text_encoder_outputs,
        "keep_tokens": keep_tokens,
        "flip_aug": False,
        "caption_extension": caption_extension,
        "enable_bucket": True,
        "bucket_no_upscale": False,
        "bucket_reso_steps": bucket_reso_steps,
        "min_bucket_reso": min_bucket_reso,
        "max_bucket_reso": max_bucket_reso,
      },
      "datasets": toml.loads(custom_dataset)["datasets"] if custom_dataset else [
        {
          "subsets": [
            {
              "num_repeats": num_repeats,
              "image_dir": images_folder,
              "class_tokens": None if caption_extension else project_name
            }
          ]
        }
      ]
    }

    for key in dataset_config_dict:
      if isinstance(dataset_config_dict[key], dict):
        dataset_config_dict[key] = {k: v for k, v in dataset_config_dict[key].items() if v is not None}

    with open(dataset_config_file, "w") as f:
      f.write(toml.dumps(dataset_config_dict))
    print(f"📄 Dataset config saved to {dataset_config_file}")


def download_model():
  global old_model_url, model_url, model_file, vae_url, vae_file
  real_model_url = model_url  # There was a reason for having a separate variable but I forgot what it was.

  if real_model_url.startswith("/content/drive/"):
    # Local model, already checked to exist
    model_file = real_model_url
    print(f"📁 Using local model file: {model_file}")

    # Download VAE
    if not os.path.exists(vae_file):
      # !aria2c "{vae_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{vae_file}"

    # Validation
    if model_file.lower().endswith(".safetensors"):
      from safetensors.torch import load_file as load_safetensors
      try:
        test = load_safetensors(model_file)
        del test
      except:
        return False
    elif model_file.lower().endswith(".ckpt"):
      from torch import load as load_ckpt
      try:
        test = load_ckpt(model_file)
        del test
      except:
        return False
    return True

  else:
    # Downloadable model
    if load_diffusers:
      if 'huggingface.co' in real_model_url:
          match = re.search(r'huggingface\.co/([^/]+)/([^/]+)', real_model_url)
          if match:
              username = match.group(1)
              model_name = match.group(2)
              model_file = f"{username}/{model_name}"
              from huggingface_hub import HfFileSystem
              fs = HfFileSystem()
              existing_folders = set(fs.ls(model_file, detail=False))
              necessary_folders = [ "scheduler", "text_encoder", "text_encoder_2", "tokenizer", "tokenizer_2", "unet", "vae" ]
              if all(f"{model_file}/{folder}" in existing_folders for folder in necessary_folders):
                print("🍃 Diffusers model identified.")  # Will be handled by kohya
                return True
      raise ValueError("💥 Failed to load Diffusers model. If this model is not Diffusers, have you tried turning it off at the top of the colab?")

    # Define local filename
    if not model_file or old_model_url and old_model_url != model_url:
      if real_model_url.lower().endswith((".ckpt", ".safetensors")):
        model_file = f"/content{real_model_url[real_model_url.rfind('/'):]}"
      else:
        model_file = "/content/downloaded_model.safetensors"
        if os.path.exists(model_file):
          # !rm "{model_file}"

    # HuggingFace
    if m := re.search(r"(?:https?://)?(?:www\.)?huggingface\.co/[^/]+/[^/]+/blob", real_model_url):
      real_model_url = real_model_url.replace("blob", "resolve")
    # Civitai
    elif m := re.search(r"(?:https?://)?(?:www\\.)?civitai\.com/models/([0-9]+)(/[A-Za-z0-9-_]+)?", real_model_url):
      if m.group(2):
        model_file = f"/content{m.group(2)}.safetensors"
      if m := re.search(r"modelVersionId=([0-9]+)", real_model_url):
        real_model_url = f"https://civitai.com/api/download/models/{m.group(1)}"
      else:
        raise ValueError("💥 optional_custom_training_model contains a civitai link, but the link doesn't include a modelVersionId. You can also right click the download button to copy the direct download link.")

    # Download checkpoint
    # !aria2c "{real_model_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{model_file}"

    # Download VAE
    if not os.path.exists(vae_file):
      # !aria2c "{vae_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{vae_file}"

    # Validation

    if model_file.lower().endswith(".safetensors"):
      from safetensors.torch import load_file as load_safetensors
      try:
        test = load_safetensors(model_file)
        del test
      except:
        new_model_file = os.path.splitext(model_file)[0]+".ckpt"
        # !mv "{model_file}" "{new_model_file}"
        model_file = new_model_file
        print(f"Renamed model to {os.path.splitext(model_file)[0]}.ckpt")

    if model_file.lower().endswith(".ckpt"):
      from torch import load as load_ckpt
      try:
        test = load_ckpt(model_file)
        del test
      except:
        return False

  return True


def calculate_rex_steps():
  # https://github.com/derrian-distro/LoRA_Easy_Training_scripts_Backend/blob/c34084b0435e6e19bb7a01ac1ecbadd185ee8c1e/utils/validation.py#L268
  global max_train_steps
  return  # importing the BucketManager broke even though the transformers version is the same, idk
  print("\n🤔 Calculating Rex steps")
  if max_train_steps:
    calculated_max_steps = max_train_steps
  else:
    from library.train_util import BucketManager
    from PIL import Image
    from pathlib import Path
    import math

    with open(dataset_config_file, "r") as f:
      subsets = toml.load(f)["datasets"][0]["subsets"]

    supported_types = [".png", ".jpg", ".jpeg", ".webp", ".bmp"]
    res = (resolution, resolution)
    bucketManager = BucketManager(False, res, min_bucket_reso, max_bucket_reso, bucket_reso_steps)
    bucketManager.make_buckets()
    for subset in subsets:
        for image in Path(subset["image_dir"]).iterdir():
            if image.suffix not in supported_types:
                continue
            with Image.open(image) as img:
                bucket_reso, _, _ = bucketManager.select_bucket(img.width, img.height)
                for _ in range(subset["num_repeats"]):
                    bucketManager.add_image(bucket_reso, image)
    steps_before_acc = sum(math.ceil(len(bucket) / train_batch_size) for bucket in bucketManager.buckets)
    calculated_max_steps = math.ceil(steps_before_acc / gradient_accumulation_steps) * max_train_epochs
    del bucketManager

  cycle_steps = calculated_max_steps // (lr_scheduler_num_cycles or 1)
  print(f"  cycle steps: {cycle_steps}")
  lr_scheduler_args.append(f"first_cycle_max_steps={cycle_steps}")

  warmup_steps = round(calculated_max_steps * lr_warmup_ratio) // (lr_scheduler_num_cycles or 1)
  if warmup_steps > 0:
    print(f"  warmup steps: {warmup_steps}")
    lr_scheduler_args.append(f"warmup_steps={warmup_steps}")


def main():
  global dependencies_installed

  if not os.path.exists('/content/drive'):
    from google.colab import drive
    print("📂 Connecting to Google Drive...")
    drive.mount('/content/drive')

  for dir in (main_dir, trainer_dir, log_folder, images_folder, output_folder, config_folder):
    os.makedirs(dir, exist_ok=True)

  if not validate_dataset():
    return

  if not dependencies_installed:
    print("\n🏭 Installing trainer...\n")
    t0 = time()
    install_trainer()
    t1 = time()
    dependencies_installed = True
    print(f"\n✅ Installation finished in {int(t1-t0)} seconds.")
  else:
    print("\n✅ Dependencies already installed.")

  if old_model_url != model_url or not model_file or not os.path.exists(model_file):
    print("\n🔄 Getting model...")
    if not download_model():
      print("\n💥 Error: The model you specified is invalid or corrupted."
            "\nIf you're using an URL, please check that the model is accessible without being logged in."
            "\nYou can try civitai or huggingface URLs, or a path in your Google Drive starting with /content/drive/MyDrive")
      return
    print()
  else:
    print("\n🔄 Model already downloaded.\n")

  if lr_scheduler_type:
    create_config()
    os.chdir(kohya_dir)
    calculate_rex_steps()
    os.chdir(root_dir)

  create_config()

  print("\n⭐ Starting trainer...\n")

  os.chdir(kohya_dir)
  # !{venv_python} {train_network} --config_file={config_file} --dataset_config={dataset_config_file}
  os.chdir(root_dir)

  if not get_ipython().__dict__['user_ns']['_exit_code']:
    display(Markdown("### ✅ Done! [Go download your Lora from Google Drive](https://drive.google.com/drive/my-drive)\n"
                     "### There will be several files, you should try the latest version (the file with the largest number next to it)"))

main()
# Out:
# 💿 Checking dataset...
# 📁MyDrive/fsces
# 📈 Found 1561 images with 1 repeats, equaling 1561 steps.
# 📉 Divide 1561 steps by 3 batch size to get 520.3333333333334 steps per epoch.
# 🔮 There will be 10 epochs, for around 5203 total training steps.
#
# ✅ Dependencies already installed.
#
# 🔄 Model already downloaded.
#
#
# 📄 Config saved to /content/drive/MyDrive/lora_training/config/zazi/training_config.toml
# 📄 Dataset config saved to /content/drive/MyDrive/lora_training/config/zazi/dataset_config.toml
#
# ⭐ Starting trainer...
#
# rich is not installed, using basic logging
# Loading settings from /content/drive/MyDrive/lora_training/config/zazi/training_config.toml...
# /content/drive/MyDrive/lora_training/config/zazi/training_config
# rich is not installed, using basic logging
# Loading dataset config from /content/drive/MyDrive/lora_training/config/zazi/dataset_config.toml
# prepare images.
# get image size from name of cache files
# 100% 1561/1561 [00:00<00:00, 467097.71it/s]
# set image size from cache files: 0/1561
# found directory /content/drive/MyDrive/fsces contains 1561 image files
# read caption:   0% 0/1561 [00:00<?, ?it/s]neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0000.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0000.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0001.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0001.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0002.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0002.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0003.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0003.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0004.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0004.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0005.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0005.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0006.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0006.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0007.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0007.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0008.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0008.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0009.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0009.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0010.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0010.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0011.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0011.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0012.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0012.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0013.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0013.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0014.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0014.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0015.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0015.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_
png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0202.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0202.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0203.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0203.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0204.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0204.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0205.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0205.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0206.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0206.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0207.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0207.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0208.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0208.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0209.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0209.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0210.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0210.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0211.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0211.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0212.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0212.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0213.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0213.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0214.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0214.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0215.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0215.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0216.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0216.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0217.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0217.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0218.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0218.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0219.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0219.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0220.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0220.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0221.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0221.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0222.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0222.png
# ...
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1923.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1923.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1924.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1924.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1927.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1927.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1929.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1929.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1932.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1932.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1934.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1934.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1937.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1937.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1940.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1940.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1942.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1942.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1943.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1943.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1944.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1944.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1945.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1945.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1947.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1947.png
# read caption:  98% 1536/1561 [00:02<00:00, 534.35it/s]neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1955.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1955.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1958.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1958.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1959.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1959.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1962.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1962.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1964.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1964.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1969.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1969.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1970.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1970.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1973.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1973.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1976.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1976.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1977.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1977.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1979.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1979.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1980.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1980.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1982.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1982.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1985.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1985.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1986.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1986.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1987.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1987.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1988.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1988.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1990.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1990.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1991.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1991.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1993.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1993.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1995.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1995.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1996.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1996.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1997.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1997.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1998.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1998.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1999.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1999.png
# read caption: 100% 1561/1561 [00:02<00:00, 613.96it/s]
# No caption file found for 1561 images. Training will continue without captions for these images. If class token exists, it will be used. / 1561枚の画像にキャプションファイルが見つかりませんでした。これらの画像についてはキャプションなしで学習を続行します。class tokenが存在する場合はそれを使います。
# /content/drive/MyDrive/fsces/face_0000.png
# /content/drive/MyDrive/fsces/face_0001.png
# /content/drive/MyDrive/fsces/face_0002.png
# /content/drive/MyDrive/fsces/face_0003.png
# /content/drive/MyDrive/fsces/face_0004.png
# /content/drive/MyDrive/fsces/face_0005.png... and 1556 more
# 1561 train images with repeating.
# 0 reg images.
# no regularization images / 正則化画像が見つかりませんでした
# [Dataset 0]
#   batch_size: 1
#   resolution: (1024, 1024)
#   enable_bucket: True
#   network_multiplier: 1.0
#   min_bucket_reso: 256
#   max_bucket_reso: 4096
#   bucket_reso_steps: 64
#   bucket_no_upscale: False
#
#   [Subset 0 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/fsces"
#     image_count: 1561
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 1
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension:
#
#
# [Dataset 0]
# loading image sizes.
# 100% 1561/1561 [00:14<00:00, 105.76it/s]
# make buckets
# number of images (including repeats) / 各bucketの画像枚数（繰り返し回数を含む）
# bucket 0: resolution (1024, 1024), count: 1561
# mean ar error (without repeats): 0.0
# preparing accelerator
# accelerator device: cuda
# loading model for process 0/1
# load StableDiffusion checkpoint: /content/sd_xl_base_1.0.safetensors
# building U-Net
# loading U-Net from checkpoint
# U-Net: <All keys matched successfully>
# building text encoders
# loading text encoders from checkpoint
# text encoder 1: <All keys matched successfully>
# text encoder 2: <All keys matched successfully>
# building VAE
# loading VAE from checkpoint
# VAE: <All keys matched successfully>
# load VAE: /content/sdxl_vae.safetensors
# exception occurs in loading vae: We couldn't connect to 'https://huggingface.co' to load this model, couldn't find it in the cached files and it looks like /content/sdxl_vae.safetensors is not the path to a directory containing a config.json file.
# Checkout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/diffusers/installation#offline-mode'.
# retry with subfolder='vae'
# Traceback (most recent call last):
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/configuration_utils.py", line 376, in load_config
#     config_file = hf_hub_download(
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py", line 101, in inner_f
#     return f(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 106, in _inner_fn
#     validate_repo_id(arg_value)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 154, in validate_repo_id
#     raise HFValidationError(
# huggingface_hub.errors.HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/content/sdxl_vae.safetensors'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/trainer/sd_scripts/library/model_util.py", line 1272, in load_vae
#     vae = AutoencoderKL.from_pretrained(vae_id, subfolder=None, torch_dtype=dtype)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/models/modeling_utils.py", line 712, in from_pretrained
#     config, unused_kwargs, commit_hash = cls.load_config(
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/configuration_utils.py", line 411, in load_config
#     raise EnvironmentError(
# OSError: We couldn't connect to 'https://huggingface.co' to load this model, couldn't find it in the cached files and it looks like /content/sdxl_vae.safetensors is not the path to a directory containing a config.json file.
# Checkout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/diffusers/installation#offline-mode'.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/configuration_utils.py", line 376, in load_config
#     config_file = hf_hub_download(
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py", line 101, in inner_f
#     return f(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 106, in _inner_fn
#     validate_repo_id(arg_value)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 154, in validate_repo_id
#     raise HFValidationError(
# huggingface_hub.errors.HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/content/sdxl_vae.safetensors'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/trainer/sd_scripts/sdxl_train_network.py", line 228, in <module>
#     trainer.train(args)
#   File "/content/trainer/sd_scripts/train_network.py", line 413, in train
#     model_version, text_encoder, vae, unet = self.load_target_model(args, weight_dtype, accelerator)
#   File "/content/trainer/sd_scripts/sdxl_train_network.py", line 50, in load_target_model
#     ) = sdxl_train_util.load_target_model(args, accelerator, sdxl_model_util.MODEL_VERSION_SDXL_BASE_V1_0, weight_dtype)
#   File "/content/trainer/sd_scripts/library/sdxl_train_util.py", line 42, in load_target_model
#     ) = _load_target_model(
#   File "/content/trainer/sd_scripts/library/sdxl_train_util.py", line 130, in _load_target_model
#     vae = model_util.load_vae(vae_path, weight_dtype)
#   File "/content/trainer/sd_scripts/library/model_util.py", line 1276, in load_vae
#     vae = AutoencoderKL.from_pretrained(vae_id, subfolder="vae", torch_dtype=dtype)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/models/modeling_utils.py", line 712, in from_pretrained
#     config, unused_kwargs, commit_hash = cls.load_config(
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/content/trainer/sd_scripts/venv/lib/python3.10/site-packages/diffusers/configuration_utils.py", line 411, in load_config
#     raise EnvironmentError(
# OSError: We couldn't connect to 'https://huggingface.co' to load this model, couldn't find it in the cached files and it looks like /content/sdxl_vae.safetensors is not the path to a directory containing a config.json file.
# Checkout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/diffusers/installation#offline-mode'.

# %% [markdown]
# ## Complete VAE Download
#
# ### Subtask:
# Ensure the Stable Diffusion XL VAE model is fully downloaded and correctly named at `/content/sdxl_vae.safetensors`.

# %% [markdown]
# **Reasoning**:
# The subtask is to ensure the VAE model is downloaded. I will use the `aria2c` command with the provided `vae_url` and `vae_file` to download the model, including the `-c` flag for resuming downloads.

# %%
print(f"Downloading VAE from {vae_url} to {vae_file}")
# !aria2c "{vae_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{vae_file}"
# Out:
# Downloading VAE from https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_vae.safetensors to /content/sdxl_vae.safetensors
#
# 03/10 13:19:51 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_vae.safetensors
# Exception: [AbstractCommand.cc:351] errorCode=3 URI=https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_vae.safetensors
#   -> [HttpSkipResponseCommand.cc:218] errorCode=3 Resource not found
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 213c71|ERR |       0B/s|//content/sdxl_vae.safetensors
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.

# %% [markdown]
# **Reasoning**:
# The previous attempt to download the VAE model failed because the resource was not found. I need to update the `vae_url` with a correct and working URL for the Stable Diffusion XL VAE model and then retry the download. I have found an updated URL from Hugging Face.

# %%
vae_url = "https://huggingface.co/stabilityai/sdxl-vae/resolve/main/sdxl_vae.safetensors"
print(f"Updating VAE URL to: {vae_url}")

print(f"Downloading VAE from {vae_url} to {vae_file}")
# !aria2c "{vae_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{vae_file}"
# Out:
# Updating VAE URL to: https://huggingface.co/stabilityai/sdxl-vae/resolve/main/sdxl_vae.safetensors
# Downloading VAE from https://huggingface.co/stabilityai/sdxl-vae/resolve/main/sdxl_vae.safetensors to /content/sdxl_vae.safetensors
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 007fb6|OK  |    80MiB/s|//content/sdxl_vae.safetensors
#
# Status Legend:
# (OK):download completed.

# %% [markdown]
# ## Re-run Setup Cell
#
# ### Subtask:
# Execute the main setup cell (`OglZzI_ujZq-`) again. This will trigger the `main()` function, which will now correctly download the VAE using the updated `vae_url` and `vae_file` variables, and then proceed with configuration and training initiation.

# %% [markdown]
# **Reasoning**:
# The subtask explicitly asks to re-run the setup cell (`OglZzI_ujZq-`) to ensure the updated VAE URL and file are used in the training process. This execution will trigger the `main()` function with the corrected VAE information.

# %% [markdown]
# **Reasoning**:
# The subtask explicitly asks to re-run the setup cell (`OglZzI_ujZq-`) to ensure the updated VAE URL and file are used in the training process. This execution will trigger the `main()` function with the corrected VAE information.

# %%
main()
# Out:
# 💿 Checking dataset...
# 📁MyDrive/fsces
# 📈 Found 1561 images with 1 repeats, equaling 1561 steps.
# 📉 Divide 1561 steps by 3 batch size to get 520.3333333333334 steps per epoch.
# 🔮 There will be 10 epochs, for around 5203 total training steps.
#
# ✅ Dependencies already installed.
#
# 🔄 Model already downloaded.
#
#
# 📄 Config saved to /content/drive/MyDrive/lora_training/config/zazi/training_config.toml
# 📄 Dataset config saved to /content/drive/MyDrive/lora_training/config/zazi/dataset_config.toml
#
# ⭐ Starting trainer...
#
# rich is not installed, using basic logging
# Loading settings from /content/drive/MyDrive/lora_training/config/zazi/training_config.toml...
# /content/drive/MyDrive/lora_training/config/zazi/training_config
# rich is not installed, using basic logging
# Loading dataset config from /content/drive/MyDrive/lora_training/config/zazi/dataset_config.toml
# prepare images.
# get image size from name of cache files
# 100% 1561/1561 [00:00<00:00, 584998.98it/s]
# set image size from cache files: 0/1561
# found directory /content/drive/MyDrive/fsces contains 1561 image files
# read caption:   0% 0/1561 [00:00<?, ?it/s]neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_
png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0177.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0177.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0178.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0178.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0179.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0179.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0180.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0180.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0181.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0181.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0182.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0182.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0183.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0183.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0184.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0184.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0185.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0185.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0186.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0186.png
# read caption:  12% 187/1561 [00:00<00:02, 656.71it/s]neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0187.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0187.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0188.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0188.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0189.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0189.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0190.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0190.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0191.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0191.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0192.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0192.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0193.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0193.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0194.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0194.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0195.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0195.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0196.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0196.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0197.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0197.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0198.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0198.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0199.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0199.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0200.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0200.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0201.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0201.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0202.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0202.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0203.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0203.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0204.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0204.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0205.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0205.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0206.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0206.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0207.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0207.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0208.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0208.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0209.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0209.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0210.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0210.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0211.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0211.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0212.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0212.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0213.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0213.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0214.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0214.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0215.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0215.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0216.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0216.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0217.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0217.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0218.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0218.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0219.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0219.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0220.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0220.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0221.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0221.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_0222.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_0222.png
# ...
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1878.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1878.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1879.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1879.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1880.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1880.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1881.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1881.png
# read caption:  96% 1501/1561 [00:02<00:00, 594.79it/s]neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1882.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1882.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1884.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1884.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1886.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1886.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1888.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1888.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1893.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1893.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1895.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1895.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1896.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1896.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1898.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1898.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1899.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1899.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1900.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1900.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1901.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1901.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1902.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1902.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1904.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1904.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1905.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1905.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1908.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1908.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1911.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1911.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1912.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1912.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1916.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1916.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1917.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1917.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1919.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1919.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1920.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1920.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1922.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1922.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1923.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1923.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1924.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1924.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1927.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1927.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1929.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1929.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1932.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1932.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1934.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1934.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1937.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1937.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1940.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1940.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1942.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1942.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1943.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1943.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1944.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1944.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1945.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1945.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1947.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1947.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1955.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1955.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1958.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1958.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1959.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1959.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1962.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1962.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1964.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1964.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1969.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1969.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1970.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1970.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1973.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1973.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1976.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1976.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1977.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1977.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1979.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1979.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1980.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1980.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1982.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1982.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1985.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1985.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1986.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1986.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1987.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1987.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1988.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1988.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1990.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1990.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1991.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1991.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1993.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1993.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1995.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1995.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1996.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1996.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1997.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1997.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1998.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1998.png
# neither caption file nor class tokens are found. use empty caption for /content/drive/MyDrive/fsces/face_1999.png / キャプションファイルもclass tokenも見つかりませんでした。空のキャプションを使用します: /content/drive/MyDrive/fsces/face_1999.png
# read caption: 100% 1561/1561 [00:02<00:00, 600.16it/s]
# No caption file found for 1561 images. Training will continue without captions for these images. If class token exists, it will be used. / 1561枚の画像にキャプションファイルが見つかりませんでした。これらの画像についてはキャプションなしで学習を続行します。class tokenが存在する場合はそれを使います。
# /content/drive/MyDrive/fsces/face_0000.png
# /content/drive/MyDrive/fsces/face_0001.png
# /content/drive/MyDrive/fsces/face_0002.png
# /content/drive/MyDrive/fsces/face_0003.png
# /content/drive/MyDrive/fsces/face_0004.png
# /content/drive/MyDrive/fsces/face_0005.png... and 1556 more
# 1561 train images with repeating.
# 0 reg images.
# no regularization images / 正則化画像が見つかりませんでした
# [Dataset 0]
#   batch_size: 1
#   resolution: (1024, 1024)
#   enable_bucket: True
#   network_multiplier: 1.0
#   min_bucket_reso: 256
#   max_bucket_reso: 4096
#   bucket_reso_steps: 64
#   bucket_no_upscale: False
#
#   [Subset 0 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/fsces"
#     image_count: 1561
#     num_repeats: 1
#     shuffle_caption: True
#     keep_tokens: 1
#     keep_tokens_separator:
#     caption_separator: ,
#     secondary_separator: None
#     enable_wildcard: False
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epochs: 0
#     caption_tag_dropout_rate: 0.0
#     caption_prefix: None
#     caption_suffix: None
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1
#     token_warmup_step: 0
#     alpha_mask: False
#     custom_attributes: {}
#     is_reg: False
#     class_tokens: None
#     caption_extension:
#
#
# [Dataset 0]
# loading image sizes.
# 100% 1561/1561 [00:13<00:00, 119.82it/s]
# make buckets
# number of images (including repeats) / 各bucketの画像枚数（繰り返し回数を含む）
# bucket 0: resolution (1024, 1024), count: 1561
# mean ar error (without repeats): 0.0
# preparing accelerator
# accelerator device: cuda
# loading model for process 0/1
# load StableDiffusion checkpoint: /content/sd_xl_base_1.0.safetensors
# building U-Net
# loading U-Net from checkpoint
# U-Net: <All keys matched successfully>
# building text encoders
# loading text encoders from checkpoint
# text encoder 1: <All keys matched successfully>
# text encoder 2: <All keys matched successfully>
# building VAE
# loading VAE from checkpoint
# VAE: <All keys matched successfully>
# load VAE: /content/sdxl_vae.safetensors
# additional VAE loaded
# Enable SDPA for U-Net
# import network module: networks.lora
# [Dataset 0]
# caching latents with caching strategy.
# caching latents...
#  18% 276/1561 [06:38<30:25,  1.42s/it]
